# %% [markdown]
# <center><img src="attachment:logo.png" style="height:100px"></center>

# %% [markdown]
# <br>
# <center><span style="font-size:35px"><b>Algorithms for Data Analysis</b></span></center>

# %% [markdown]
# <center><span style="font-size:25px"><b>Lab1: First Steps of Data Analysis | Video Games Sales</b></span></center>

# %% [markdown]
# The Video Games Sales dataset contains a list of video games with sales greater than 100,000 copies. It is a treasure trove of information, containing details on global sales, publishers, regions, and other key variables within the gaming industry.
# In this Jupyter Notebook, we follow the first three crucial stages of the data analysis pipeline applied to this dataset: Collection, Cleaning, and Exploratory Data Analysis (EDA).

# %% [markdown]
# ![data%20%28copie%29.png](attachment:data%20%28copie%29.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 1. Collection
#
# We've already gathered relevant data by employing a Python script to scrape information from https://www.vgchartz.com (https://github.com/GregorUT/vgchartzScrape) into the *vgsales.csv* file. This meticulous data collection lays the groundwork for subsequent analyses.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Use the Panda library to load the *vgsales.csv* dataset into a Pandas serie called ``data``. Then, display the first $10$ entries

# %% [markdown]
# # 2. Cleaning
#
# In this section, we delve into refining the dataset, addressing inconsistencies, handling missing values, and ensuring data integrity.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Display the shape of the dataset. Comment.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Check for missing values. How many missing values are there per categories?

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Check for duplicate rows. What do you find?

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Remove the missing values and duplicate rows. Then, reset the indices so that deleted rows do not appear anymore.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Provide a summary of your data after the cleaning process

# %% [markdown]
# # 3. Exploratory Data Analysis
#
# In this final section, we unravel key insights as we explore questions such as top-performing publishers, regional sales variations, and potential correlations between sales.

# %% [markdown]
# ## 3.1. First Insights

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Provide descriptive statistics of the dataset.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Calculate and display the correlation matrix between the sales in each region as well as the global sales. Comment.

# %% [markdown]
# ## 3.2. Global Sales By Year

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Create a variable `global_sales_by_year` containing all the global sales group by year.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Plot the global sales of the years.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Identify the most selling year using built-in functions.

# %% [markdown]
# ## 3.3. Top Publishers

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Calculate the percentage of global sales for each publisher.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Create a bar chart illustrating the percentage of global sales for each publisher

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Select the top 10 publishers with the highest global sales in a variable name `top_publishers`. Display them and their global sales.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** The `np.eye` function in NumPy is used to create a 2-D identity matrix. It is generally used for linear algebra operations and matrix manipulations. Use `np.eye` to create a binary indicator matrix such that the value is 1 if the top publisher in the row has higher global sales than the top publisher in the column.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.** Display your results using a heatmap.

# %% [markdown]
# ## 3.4. To Go Further

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCICE.**. You are a EU-based publishing company. You would like to find, based on the EU sales, if your game will also be well sold abroad. What kind of exploratory data analysis can you think of?
